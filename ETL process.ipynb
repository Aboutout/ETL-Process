# %% [markdown]
# # 04/03/2019
# Reading or Extracting from database

# %%
import os
folder_content=os.listdir("/home/ankit/Desktop/Internship/")

# %%
error_msg="database is not available"
assert "database.sqlite" in folder_content, error_msg

# %%
import sqlite3

# %%
conn=sqlite3.connect("/home/ankit/Desktop/Internship/database.sqlite")

# %%
cursor=conn.cursor()

# %%
type(cursor)
# Out:
# sqlite3.Cursor

# %%
cursor.execute("select name from sqlite_master").fetchall()
# Out:
# [('Iris',)]

# %%
data=cursor.execute("select * from Iris limit 50").fetchall()

# %%
type(data)
# Out:
# list

# %%
data
# Out:
# [(1, 5.1, 3.5, 1.4, 0.2, 'Iris-setosa'),
#  (2, 4.9, 3, 1.4, 0.2, 'Iris-setosa'),
#  (3, 4.7, 3.2, 1.3, 0.2, 'Iris-setosa'),
#  (4, 4.6, 3.1, 1.5, 0.2, 'Iris-setosa'),
#  (5, 5, 3.6, 1.4, 0.2, 'Iris-setosa'),
#  (6, 5.4, 3.9, 1.7, 0.4, 'Iris-setosa'),
#  (7, 4.6, 3.4, 1.4, 0.3, 'Iris-setosa'),
#  (8, 5, 3.4, 1.5, 0.2, 'Iris-setosa'),
#  (9, 4.4, 2.9, 1.4, 0.2, 'Iris-setosa'),
#  (10, 4.9, 3.1, 1.5, 0.1, 'Iris-setosa'),
#  (11, 5.4, 3.7, 1.5, 0.2, 'Iris-setosa'),
#  (12, 4.8, 3.4, 1.6, 0.2, 'Iris-setosa'),
#  (13, 4.8, 3, 1.4, 0.1, 'Iris-setosa'),
#  (14, 4.3, 3, 1.1, 0.1, 'Iris-setosa'),
#  (15, 5.8, 4, 1.2, 0.2, 'Iris-setosa'),
#  (16, 5.7, 4.4, 1.5, 0.4, 'Iris-setosa'),
#  (17, 5.4, 3.9, 1.3, 0.4, 'Iris-setosa'),
#  (18, 5.1, 3.5, 1.4, 0.3, 'Iris-setosa'),
#  (19, 5.7, 3.8, 1.7, 0.3, 'Iris-setosa'),
#  (20, 5.1, 3.8, 1.5, 0.3, 'Iris-setosa'),
#  (21, 5.4, 3.4, 1.7, 0.2, 'Iris-setosa'),
#  (22, 5.1, 3.7, 1.5, 0.4, 'Iris-setosa'),
#  (23, 4.6, 3.6, 1, 0.2, 'Iris-setosa'),
# ...

# %%
cursor.execute("SELECT sql FROM sqlite_master WHERE tbl_name = 'Iris' AND type = 'table'").fetchall()
# Out:
# [('CREATE TABLE Iris (\n    Id INTEGER PRIMARY KEY,\n    SepalLengthCm NUMERIC,\n    SepalWidthCm NUMERIC,\n    PetalLengthCm NUMERIC,\n    PetalWidthCm NUMERIC,\n    Species TEXT)',)]

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
data2=pd.read_sql_query("select * from Iris", conn)

# %%
data2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data2.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
data3=pd.read_sql_query("select * from Iris",conn)

# %%
data3
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %% [markdown]
# # CSV file extracting

# %%
csv_file=pd.read_csv("/home/ankit/Desktop/Internship/Iris.csv",names=['PetalWidthCm' ,'Species'],header=10)

# %%
csv_file.head(10)
# Out:
#                 PetalWidthCm      Species
# 11 5.4 3.7 1.5           0.2  Iris-setosa
# 12 4.8 3.4 1.6           0.2  Iris-setosa
# 13 4.8 3.0 1.4           0.1  Iris-setosa
# 14 4.3 3.0 1.1           0.1  Iris-setosa
# 15 5.8 4.0 1.2           0.2  Iris-setosa
# 16 5.7 4.4 1.5           0.4  Iris-setosa
# 17 5.4 3.9 1.3           0.4  Iris-setosa
# 18 5.1 3.5 1.4           0.3  Iris-setosa
# 19 5.7 3.8 1.7           0.3  Iris-setosa
# 20 5.1 3.8 1.5           0.3  Iris-setosa

# %%
csv_file['PetalWidthCm'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # .txt file Reading using pandas

# %%
csv_file=pd.read_csv("/home/ankit/Desktop/Internship/Iris.txt",header=[1,2,3])

# %%
type(csv_file)
# Out:
# pandas.core.frame.DataFrame

# %%
csv_file
# Out:
#        1  5.1  3.5  1.4  0.2     Iris-setosa
#        2  4.9  3.0  1.4  0.2     Iris-setosa
#        3  4.7  3.2  1.3  0.2     Iris-setosa
# 0      4  4.6  3.1  1.5  0.2     Iris-setosa
# 1      5  5.0  3.6  1.4  0.2     Iris-setosa
# 2      6  5.4  3.9  1.7  0.4     Iris-setosa
# 3      7  4.6  3.4  1.4  0.3     Iris-setosa
# 4      8  5.0  3.4  1.5  0.2     Iris-setosa
# 5      9  4.4  2.9  1.4  0.2     Iris-setosa
# 6     10  4.9  3.1  1.5  0.1     Iris-setosa
# 7     11  5.4  3.7  1.5  0.2     Iris-setosa
# 8     12  4.8  3.4  1.6  0.2     Iris-setosa
# 9     13  4.8  3.0  1.4  0.1     Iris-setosa
# 10    14  4.3  3.0  1.1  0.1     Iris-setosa
# 11    15  5.8  4.0  1.2  0.2     Iris-setosa
# 12    16  5.7  4.4  1.5  0.4     Iris-setosa
# 13    17  5.4  3.9  1.3  0.4     Iris-setosa
# 14    18  5.1  3.5  1.4  0.3     Iris-setosa
# 15    19  5.7  3.8  1.7  0.3     Iris-setosa
# 16    20  5.1  3.8  1.5  0.3     Iris-setosa
# 17    21  5.4  3.4  1.7  0.2     Iris-setosa
# ...

# %%
csv_file.isnull().all()
# Out:
# 1            2            3              False
# 5.1          4.9          4.7            False
# 3.5          3.0          3.2            False
# 1.4          1.4          1.3            False
# 0.2          0.2          0.2            False
# Iris-setosa  Iris-setosa  Iris-setosa    False
# dtype: bool

# %%
X=data3[['SepalLengthCm','SepalWidthCm', 'PetalLengthCm' ,'PetalWidthCm']]

# %%
y=data3['Species']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=450)

# %% [markdown]
# # 05/03/2019

# %%
import pandas as pd
movies=pd.read_csv("/home/ankit/Desktop/Internship/ml-20m/movies.csv")
tags=pd.read_csv("/home/ankit/Desktop/Internship/ml-20m/tags.csv")
ratings=pd.read_csv("/home/ankit/Desktop/Internship/ml-20m/ratings.csv",parse_dates=['timestamp'])

# %%
ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1        2     3.5  1112486027
# 1              1       29     3.5  1112484676
# 2              1       32     3.5  1112484819
# 3              1       47     3.5  1112484727
# 4              1       50     3.5  1112484580
# 5              1      112     3.5  1094785740
# 6              1      151     4.0  1094785734
# 7              1      223     4.0  1112485573
# 8              1      253     4.0  1112484940
# 9              1      260     4.0  1112484826
# 10             1      293     4.0  1112484703
# 11             1      296     4.0  1112484767
# 12             1      318     4.0  1112484798
# 13             1      337     3.5  1094785709
# 14             1      367     3.5  1112485980
# 15             1      541     4.0  1112484603
# 16             1      589     3.5  1112485557
# 17             1      593     3.5  1112484661
# 18             1      653     3.0  1094785691
# ...

# %%
movies.iloc[[0,22,125]]
# Out:
#      movieId                                              title  \
# 0          1                                   Toy Story (1995)
# 22        23                                   Assassins (1995)
# 125      127  Silences of the Palace, The (Saimt el Qusur) (...
#
#                                           genres
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 22                         Action|Crime|Thriller
# 125                                        Drama

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
s=ratings['rating'].describe()

# %%
s.index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
ratings['rating'].mean()
# Out:
# 3.5255285642993797

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
tags.isnull().any()
# Out:
# userId       False
# movieId      False
# tag          False
# timestamp    False
# dtype: bool

# %%
tags=tags.dropna()

# %%
tags.shape
# Out:
# (465548, 4)

# %%
# %matplotlib inline
ratings.hist(column='rating', figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f80582f45c0>]],
#       dtype=object)

# %%
ratings.boxplot(column='rating')

# %%
highly_rated=ratings['rating']>4.0

# %%
ratings[highly_rated][3:5]
# Out:
#      userId  movieId  rating   timestamp
# 142       1     5952     5.0  1112484619
# 158       1     7153     5.0  1112484633

# %%
count_rating=ratings[['movieId','rating']].groupby('movieId').mean()

# %%
type(count_rating)
# Out:
# pandas.core.frame.DataFrame

# %%
count_rating
# Out:
#            rating
# movieId
# 1        3.921240
# 2        3.211977
# 3        3.151040
# 4        2.861393
# 5        3.064592
# 6        3.834930
# 7        3.366484
# 8        3.142049
# 9        3.004924
# 10       3.430029
# 11       3.667713
# 12       2.619766
# 13       3.272416
# 14       3.432082
# 15       2.721993
# 16       3.787455
# 17       3.968573
# 18       3.373631
# 19       2.607412
# 20       2.880754
# 21       3.581689
# 22       3.319400
# 23       3.148235
# 24       3.199849
# 25       3.689510
# 26       3.628857
# 27       3.413520
# 28       4.057546
# 29       3.952230
# 30       3.633880
# ...           ...
# 131146   4.000000
# 131148   4.000000
# 131150   4.000000
# 131152   0.500000
# 131154   3.500000
# 131156   4.000000
# 131158   4.000000
# 131160   4.000000
# 131162   2.000000
# 131164   4.000000
# 131166   4.000000
# 131168   3.500000
# 131170   3.500000
# 131172   1.000000
# 131174   3.500000
# 131176   4.500000
# 131180   2.500000
# ...
